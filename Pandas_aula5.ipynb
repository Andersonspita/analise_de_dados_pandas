# %%
import pandas as pd

# %%
#leitura de arquivos
df1 = pd.read_excel("Aracaju.xlsx")
df2 = pd.read_excel("Fortaleza.xlsx")
df3 = pd.read_excel("Natal.xlsx")
df4 = pd.read_excel("Recife.xlsx")
df5 = pd.read_excel("Salvador.xlsx")

# %%
#juntando todos os arquivos
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df.head(100)
# Out:
#      Cidade       Data  Vendas  LojaID  Qtde
# 0   Aracaju 2018-01-01  142.00    1520     1
# 1   Aracaju 2018-01-01   14.21    1522     6
# 2   Aracaju 2018-01-01   71.55    1520     1
# 3   Aracaju 2018-01-01    3.01    1521     7
# 4   Aracaju 2018-01-01   24.51    1522     8
# ..      ...        ...     ...     ...   ...
# 95  Aracaju 2018-01-01  127.43    1522     9
# 96  Aracaju 2018-01-01   85.92    1521     2
# 97  Aracaju 2018-01-01   32.69    1521     5
# 98  Aracaju 2018-01-01  138.33    1521    10
# 99  Aracaju 2018-01-01  139.32    1521     3
#
# [100 rows x 5 columns]

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %%
#Consultando linhas com valores nulos
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
#Substituindo valores nulos por zero
df["Vendas"].fillna(0, inplace=True)

# %%
#Apagando linhas com valores nulos
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
#Apagando linhas com valores nulos com base apenas em 1 coluna
df.dropna(subset=["Vendas"], inplace=True)

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
#removendo linhas com valores falyantes em todas as colunas
df.dropna(how="all", inplace=True)

# %%
#Criando novas colunas
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
#retornando maior receita
df["Receita"].max()
# Out:
# 3544.0

# %%
#retornando menor receita
df["Receita"].min()
# Out:
# 3.34

# %%
#Top n maiores receitas
df.nlargest(3, "Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0

# %%
#top n menores receitas
df.nsmallest(3, "Receita")
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34
# 65    Recife 2019-01-01    4.01    981     1     4.01
# 92     Natal 2019-01-02    4.57   1035     1     4.57

# %%
#Agrupando por cidade
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
df.sort_values("Receita", ascending=True).head(10)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita
# 118   Aracaju 2018-01-01    3.34   1522     1     3.34
# 65     Recife 2019-01-01    4.01    981     1     4.01
# 92   Salvador 2019-01-01    4.57   1035     1     4.57
# 92      Natal 2019-01-02    4.57   1035     1     4.57
# 95   Salvador 2019-01-01    5.13   1035     1     5.13
# 95      Natal 2019-01-02    5.13   1035     1     5.13
# 161  Salvador 2019-01-02    5.80   1036     1     5.80
# 161     Natal 2019-01-02    5.80   1036     1     5.80
# 216     Natal 2019-01-02    5.82   1035     1     5.82
# 216  Salvador 2019-01-02    5.82   1035     1     5.82

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
df["Data"] = df["Data"].astype("int64")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   """Entry point for launching an IPython kernel.

# %%
df.dtypes
# Out:
# Cidade      object
# Data         int64
# Vendas     float64
# LojaID      object
# Qtde         int64
# Receita    float64
# dtype: object

# %%
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade             object
# Data       datetime64[ns]
# Vendas            float64
# LojaID             object
# Qtde                int64
# Receita           float64
# dtype: object

# %%
#Agrupamento por ano
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
#Criando nova coluna com ano
df["Ano_venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda
# 76    Salvador 2019-01-01   39.51   1035     3   118.53       2019
# 141     Recife 2019-03-02  182.75    983     8  1462.00       2019
# 0       Recife 2019-01-01  162.61    981     1   162.61       2019
# 64   Fortaleza 2019-01-01  110.31   1005     4   441.24       2019
# 115   Salvador 2019-03-02  202.33   1035     2   404.66       2019

# %%
df["mes_venda"], df["dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  mes_venda  \
# 113  Fortaleza 2019-03-02   38.63    980     2    77.26       2019          3
# 208      Natal 2019-01-02   39.40   1036     3   118.20       2019          1
# 15   Fortaleza 2019-01-01  195.05   1002     2   390.10       2019          1
# 229      Natal 2019-01-02   43.08   1036     2    86.16       2019          1
# 90       Natal 2019-01-02  100.54   1036     2   201.08       2019          1
#
#      dia_venda
# 113          2
# 208          2
# 15           1
# 229          2
# 90           2

# %%
#Data mais antiga
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
#Diferença de dias
df["Diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample()
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  mes_venda  \
# 224  Salvador 2019-01-02   178.3   1035     3    534.9       2019          1
#
#      dia_venda Difereca_dias Diferenca_dias  Trimestre_venda
# 224          2      459 days       366 days                1

# %%
df.drop(columns="Difereca_dias")
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  mes_venda  \
# 0     Aracaju 2018-01-01  142.00   1520     1   142.00       2018          1
# 1     Aracaju 2018-01-01   14.21   1522     6    85.26       2018          1
# 2     Aracaju 2018-01-01   71.55   1520     1    71.55       2018          1
# 3     Aracaju 2018-01-01    3.01   1521     7    21.07       2018          1
# 4     Aracaju 2018-01-01   24.51   1522     8   196.08       2018          1
# ..        ...        ...     ...    ...   ...      ...        ...        ...
# 235  Salvador 2019-01-03   41.84   1034     1    41.84       2019          1
# 236  Salvador 2019-01-03  126.29   1035     3   378.87       2019          1
# 237  Salvador 2019-01-03   38.06   1036     3   114.18       2019          1
# 238  Salvador 2019-01-03  139.64   1035     1   139.64       2019          1
# 239  Salvador 2019-01-03  161.41   1037     3   484.23       2019          1
#
# ...

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  mes_venda  \
# 22    Aracaju 2018-01-01  150.94   1522     1   150.94       2018          1
# 208     Natal 2019-01-02   39.40   1036     3   118.20       2019          1
# 170  Salvador 2019-01-02    9.26   1035     3    27.78       2019          1
# 155     Natal 2019-01-02  237.81   1036     3   713.43       2019          1
# 175     Natal 2019-01-02   16.53   1036     2    33.06       2019          1
#
#      dia_venda Difereca_dias Diferenca_dias  Trimestre_venda
# 22           1      459 days         0 days                1
# 208          2      459 days       366 days                1
# 170          2      459 days       366 days                1
# 155          2      459 days       366 days                1
# 175          2      459 days       366 days                1

# %%
df["Trimestre_venda"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  mes_venda  \
# 78   Fortaleza 2019-01-01   37.66   1005     2    75.32       2019          1
# 229      Natal 2019-01-02   43.08   1036     2    86.16       2019          1
# 40       Natal 2018-01-10  885.00    853     3  2655.00       2018          1
# 53    Salvador 2019-01-01   39.50   1035     3   118.50       2019          1
# 63      Recife 2019-01-01   37.95    980     2    75.90       2019          1
#
#      dia_venda Difereca_dias Diferenca_dias  Trimestre_venda
# 78           1      459 days       365 days                1
# 229          2      459 days       366 days                1
# 40          10      459 days         9 days                1
# 53           1      459 days       365 days                1
# 63           1      459 days       365 days                1

# %%
#Filtrando as vendas de 2019 do mês de março
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  mes_venda  \
# 108  Fortaleza 2019-03-02  152.89    981     4   611.56       2019          3
# 109  Fortaleza 2019-03-02   18.90    982     6   113.40       2019          3
# 110  Fortaleza 2019-03-02   51.98    983     6   311.88       2019          3
# 111  Fortaleza 2019-03-02    8.00    981     3    24.00       2019          3
# 112  Fortaleza 2019-03-02  133.59    982     1   133.59       2019          3
# ..         ...        ...     ...    ...   ...      ...        ...        ...
# 137   Salvador 2019-03-02   51.66   1036     3   154.98       2019          3
# 138   Salvador 2019-03-02  212.03   1037     3   636.09       2019          3
# 139   Salvador 2019-03-02  169.01   1036     1   169.01       2019          3
# 140   Salvador 2019-03-02   20.79   1036     2    41.58       2019          3
# 141   Salvador 2019-03-02    9.08   1036     1     9.08       2019          3
#
# ...

# %%
df.drop(columns="Difereca_dias")
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  mes_venda  \
# 0     Aracaju 2018-01-01  142.00   1520     1   142.00       2018          1
# 1     Aracaju 2018-01-01   14.21   1522     6    85.26       2018          1
# 2     Aracaju 2018-01-01   71.55   1520     1    71.55       2018          1
# 3     Aracaju 2018-01-01    3.01   1521     7    21.07       2018          1
# 4     Aracaju 2018-01-01   24.51   1522     8   196.08       2018          1
# ..        ...        ...     ...    ...   ...      ...        ...        ...
# 235  Salvador 2019-01-03   41.84   1034     1    41.84       2019          1
# 236  Salvador 2019-01-03  126.29   1035     3   378.87       2019          1
# 237  Salvador 2019-01-03   38.06   1036     3   114.18       2019          1
# 238  Salvador 2019-01-03  139.64   1035     1   139.64       2019          1
# 239  Salvador 2019-01-03  161.41   1037     3   484.23       2019          1
#
# ...

# %%
#Filtrando as vendas de 2019 do mês de março
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19.sample(10)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_venda  mes_venda  \
# 135     Recife 2019-03-02   10.79    983     5    53.95       2019          3
# 118     Recife 2019-03-02   17.70    981     5    88.50       2019          3
# 122   Salvador 2019-03-02   13.27   1037     1    13.27       2019          3
# 111     Recife 2019-03-02    8.00    981     3    24.00       2019          3
# 42       Natal 2019-03-02  775.00    854     2  1550.00       2019          3
# 71       Natal 2019-03-20  840.00    854     3  2520.00       2019          3
# 114  Fortaleza 2019-03-02   16.82    983     4    67.28       2019          3
# 129     Recife 2019-03-02   35.34    982     7   247.38       2019          3
# 129  Fortaleza 2019-03-02   35.34    982     7   247.38       2019          3
# 108  Fortaleza 2019-03-02  152.89    981     4   611.56       2019          3
#
#      dia_venda Difereca_dias Diferenca_dias  Trimestre_venda
# ...

# %% [markdown]
# ## **Visualização de dados**

# %%
df["LojaID"].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df["LojaID"].value_counts(ascending=False).plot.bar()

# %%
df["LojaID"].value_counts(ascending=False).plot.barh();

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie();

# %%
#Total vendas por cidade
df["Cidade"].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
#Adicionando um título e alterando o nome dos eixos
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
#Alterando a cor do gráfico
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade", color="red")
plt.xlabel("Cidade")
plt.ylabel("Total vendas");

# %%
#Alterando o estilo
plt.style.use("ggplot")

# %%
df.groupby(df["mes_venda"])["Qtde"].sum().plot(title="Total Produtos Vendidos por Mês")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos");
plt.legend()

# %%
df.groupby(df["mes_venda"])["Qtde"].sum()
# Out:
# mes_venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
#Selecionando apenas vendas de 2019
df_2019 = df[df["Ano_venda"] == 2019]

# %%
#Total de produtos vendidos por mês em 2019
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum().plot(marker="v", title="Total Produtos vendidos por mês (ANO 2019)")
plt.xlabel("Mês")
plt.ylabel("Total Produtos vendidos");
plt.legend()
